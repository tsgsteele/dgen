# %%
# Adjust the PV and battery price trajectories for the baseline and policy
# scenarios, then upload them to the Cloud SQL instance.
#
# ============================================================================
# POLICY SCENARIOS (toggle in cell 6 via POLICY_SCENARIO) -- BOTH preserved:
#
#   "immediate_1w"       $1/W PV & $800/kWh batt in 2026, then -2%/-5%/yr.
#                        ORIGINAL run -> Results/Updated tariffs/
#                        (RUN_ID run_all_states_updated_tariffs).
#
#   "linear_to_1w_2036"  Start at baseline 2026 price, linear to target by 2036,
#                        then -2%/-5%/yr. Rockefeller run.
#
# Each trajectory is versioned to
#   input_data/pv_plus_batt_prices/policy_trajectory_<POLICY_SCENARIO>.csv
# so neither is ever lost. Flip the toggle + re-run to restore either one in
# the DB (upload OVERWRITES diffusion_shared.*_dollar_per_watt).
#
# AVOID MIXING UP RUNS:
#   - Result schemas in Cloud SQL keep unique timestamps, so old schemas are
#     never overwritten -- but new policy schemas share the old names except
#     for a newer timestamp. Note the run date/timestamp.
#   - When downloading results, use a RUN_ID that matches POLICY_SCENARIO
#     (e.g. run_all_states_linear_to_1w) so output folders never collide.
# ============================================================================

# %%
# Imports
import sys, os
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

sys.path.append(os.path.abspath(".."))

from input_data_functions import stacked_sectors

# %%
# Load data
pv = pd.read_csv('../../input_data/pv_prices/pv_price_atb23_mid.csv')
batt = pd.read_csv('../../input_data/batt_prices/batt_prices_FY23_mid.csv')
pv_batt = pd.read_csv('../../input_data/pv_plus_batt_prices/pv_plus_batt_prices_FY23_mid.csv') 
inflation = pd.read_csv('../../../data/inflation_multipliers.csv')

# %%
# --- Baseline PV & battery cost anchors (2026 starting point) ---
# PV: the national median comes from LBNL's 2025 PUBLISHED state table, via
#     dgen_os/input_data/state_upfront_cost_lbnl_2025.csv (built in "build_baseline_upfront_cost").
#     Per-STATE PV prices are applied later in the state-specific cell; this national figure is
#     only the linear-policy ramp start and the pre-override national anchor.
#
# Battery ($/kWh): stays a 2024 value on purpose -- NOT updated to 2025. Why:
#   (1) LBNL does NOT publish an aggregated storage $/kWh in the state download (the xlsx has
#       battery_attachment_rate but no battery price), so the only 2025 source is the row-level
#       TTS file, and
#   (2) the row-level 2025 storage price is too thin/noisy to trust: RES-only 2025 median is
#       ~$2,077/kWh on n=177 (obvious noise), and RES+RES_SF is ~$1,549/kWh -- a ~28% jump over
#       2024 that is a data-mix artifact, not real battery-cost inflation (battery $/kWh has been
#       flat-to-declining).
#   So we keep the stable 2024 residential storage median ($1,199.3/kWh, inflation-adjusted, from
#   the TTS 29-Sep-2025 release). NOTE this is an ALL-IN installed $/kWh: financial_functions uses
#   a single per-kWh term for battery cost (no separate power / linear_constant adder), then applies
#   a 0.7 ITC factor -> effective ~$840/kWh. Revisit if LBNL publishes a clean 2025 storage price.
_costs = pd.read_csv('../../input_data/state_upfront_cost_lbnl_2025.csv')
median_price_pv_per_kw    = float(_costs.loc[_costs['state'] == 'National', 'upfront_cost_per_w'].iloc[0]) * 1000.0
median_price_batt_per_kwh = 1199.3   # $/kWh -- LBNL TTS 2024 residential storage median (see note above)

assert pd.notna(median_price_pv_per_kw) and median_price_pv_per_kw > 0, "PV national median missing from CSV."
print(f"PV national median  = {median_price_pv_per_kw:,.1f} $/kW  ({median_price_pv_per_kw/1000:.4f} $/W)  [LBNL 2025 published]")
print(f"Battery median      = {median_price_batt_per_kwh:,.1f} $/kWh  [LBNL TTS 2024 storage -- 2025 too noisy to use]")
# Out:
# PV national median  = 3,615.9 $/kW  (3.6159 $/W)  [LBNL 2025 published]
# Battery median      = 1,199.3 $/kWh  [LBNL TTS 2024 storage -- 2025 too noisy to use]

# %%
# --- Policy price scenarios -------------------------------------------------
# Choose which policy assumption to build & upload. BOTH are preserved here as
# code and as versioned CSVs, so neither scenario is ever lost -- flip the
# toggle and re-run this notebook to restore whichever you want in the DB.
#
#   "immediate_1w"       : $1/W PV & $800/kWh batt in 2026, then -2%/-5%/yr.
#                          The ORIGINAL run -> Results/Updated tariffs/
#                          (RUN_ID run_all_states_updated_tariffs).
#   "linear_to_1w_2036"  : start at the baseline 2026 price, decline linearly to
#                          target ($1/W PV, $800/kWh batt) by 2036, then
#                          -2%/-5%/yr. The Rockefeller run.
# ---------------------------------------------------------------------------

POLICY_SCENARIO = "immediate_1w"   # <-- set to "immediate_1w" to rebuild the original

years        = np.arange(2026, 2051)    # 2026..2050 inclusive
START_YEAR   = 2026
TARGET_PV    = 1000    # $/kW == $1.00/W
TARGET_BATT  = 800     # $/kWh
DECLINE_PV   = 0.02    # 2%/yr
DECLINE_BATT = 0.05    # 5%/yr

if POLICY_SCENARIO == "immediate_1w":
    # Jump straight to target in 2026, then decline.
    prices_pv   = TARGET_PV   * ((1 - DECLINE_PV)  ** (years - START_YEAR))
    prices_batt = TARGET_BATT * ((1 - DECLINE_BATT) ** (years - START_YEAR))

elif POLICY_SCENARIO == "linear_to_1w_2036":
    # Start at baseline 2026 price, linear to target by 2036, then decline.
    LINEAR_YEARS = 10
    KNEE_YEAR    = START_YEAR + LINEAR_YEARS   # 2036: target first reached
    START_PV     = median_price_pv_per_kw      # = baseline scenario's 2026 price
    START_BATT   = median_price_batt_per_kwh

    def ramp_then_decline(years, start, target, decline,
                          start_year=START_YEAR, knee_year=KNEE_YEAR, linear_years=LINEAR_YEARS):
        """Linear from `start` (start_year) to `target` (knee_year), then geometric decline."""
        frac   = np.clip((years - start_year) / linear_years, 0, 1)
        linear = start + (target - start) * frac
        post   = target * (1 - decline) ** (years - knee_year)
        return np.where(years <= knee_year, linear, post)

    prices_pv   = ramp_then_decline(years, START_PV,   TARGET_PV,   DECLINE_PV)
    prices_batt = ramp_then_decline(years, START_BATT, TARGET_BATT, DECLINE_BATT)

else:
    raise ValueError(f"Unknown POLICY_SCENARIO: {POLICY_SCENARIO!r}")

price_df = pd.DataFrame({"year": years, "price_pv": prices_pv, "price_batt": prices_batt})

# Version the trajectory so every scenario stays reproducible after the DB
# tables are overwritten on upload (cell 8).
_traj_path = f"../../input_data/pv_plus_batt_prices/policy_trajectory_{POLICY_SCENARIO}.csv"
price_df.round(2).to_csv(_traj_path, index=False)

_y = price_df.set_index("year")
print(f"Policy scenario: {POLICY_SCENARIO}")
print(f"  PV      2026={_y.loc[2026,'price_pv']:,.0f} $/kW  2036={_y.loc[2036,'price_pv']:,.0f}  2050={_y.loc[2050,'price_pv']:,.0f}")
print(f"  Battery 2026={_y.loc[2026,'price_batt']:,.0f} $/kWh  2036={_y.loc[2036,'price_batt']:,.0f}  2050={_y.loc[2050,'price_batt']:,.0f}")
print(f"  Saved trajectory -> {_traj_path}\n")
print(price_df.round(1).to_string(index=False))
# Out:
# Policy scenario: immediate_1w
#   PV      2026=1,000 $/kW  2036=817  2050=616
#   Battery 2026=800 $/kWh  2036=479  2050=234
#   Saved trajectory -> ../../input_data/pv_plus_batt_prices/policy_trajectory_immediate_1w.csv
#
#  year  price_pv  price_batt
#  2026    1000.0       800.0
#  2027     980.0       760.0
#  2028     960.4       722.0
#  2029     941.2       685.9
#  2030     922.4       651.6
#  2031     903.9       619.0
#  2032     885.8       588.1
#  2033     868.1       558.7
#  2034     850.8       530.7
#  2035     833.7       504.2
#  2036     817.1       479.0
#  2037     800.7       455.0
#  2038     784.7       432.3
#  2039     769.0       410.7
#  2040     753.6       390.1
#  2041     738.6       370.6
#  2042     723.8       352.1
#  2043     709.3       334.5
#  2044     695.1       317.8
#  2045     681.2       301.9
#  2046     667.6       286.8
#  2047     654.3       272.4
#  2048     641.2       258.8
#  2049     628.3       245.9
# ...

# %%
# --- Baseline ---

# For PV adjust the price trajectory with the LBNL median as the 2025 price
pv['system_capex_per_kw_res'] = pv['system_capex_per_kw_res'] * (median_price_pv_per_kw / pv[pv['year'] == 2026]['system_capex_per_kw_res'].values[0])
pv_batt['system_capex_per_kw_res'] = pv_batt['system_capex_per_kw_res'] * (median_price_pv_per_kw / pv_batt[pv_batt['year'] == 2026]['system_capex_per_kw_res'].values[0])

# Same for batteries
batt['batt_capex_per_kwh_res'] = pv_batt['batt_capex_per_kwh_res'] * (median_price_batt_per_kwh / pv_batt[pv_batt['year'] == 2026]['batt_capex_per_kwh_res'].values[0]) 
pv_batt['batt_capex_per_kwh_res'] = pv_batt['batt_capex_per_kwh_res'] * (median_price_batt_per_kwh / pv_batt[pv_batt['year'] == 2026]['batt_capex_per_kwh_res'].values[0])

# Adjust for only after 2026
pv = pv[pv['year'] >= 2026]
pv_batt = pv_batt[pv_batt['year'] >= 2026]
batt = batt[batt['year']>= 2026]

# --- Dollar per watt ---

# First create new DFs
pv_dollar_per_watt = pv.copy().reset_index(drop=True)
batt_dollar_per_watt = batt.copy().reset_index(drop=True)
pv_batt_dollar_per_watt = pv_batt.copy().reset_index(drop=True)

# Adjust relevant columns for dollar per watt
pv_dollar_per_watt['system_capex_per_kw_res'] = price_df['price_pv']
pv_batt_dollar_per_watt['system_capex_per_kw_res'] = price_df['price_pv']
batt_dollar_per_watt['batt_capex_per_kwh_res'] = price_df['price_batt']
pv_batt_dollar_per_watt['batt_capex_per_kwh_res'] = price_df['price_batt']

# Apply the same functions as dGen so data is in proper format
pv = stacked_sectors(pv)
pv_batt = stacked_sectors(pv_batt)
batt = stacked_sectors(batt)

pv_dollar_per_watt = stacked_sectors(pv_dollar_per_watt)
pv_batt_dollar_per_watt = stacked_sectors(pv_batt_dollar_per_watt)
batt_dollar_per_watt = stacked_sectors(batt_dollar_per_watt)

# %%
# --- STATE-SPECIFIC baseline PV capex (pv_price AND pv_plus_batt) -----------------------
# Re-anchor the national ATB decline shape to each state's 2026 upfront cost from the LBNL
# 2025 published state medians (dgen_os/input_data/state_upfront_cost_lbnl_2025.csv, built in the
# "build_baseline_upfront_cost" notebook). Every state keeps the SAME ATB decline shape;
# only the 2026 starting level differs. That CSV already bakes in the sufficiency rule
# (states with <100 priced installs carry the national median), so we use its value directly.
# Only the PV cost (system_capex_per_kw) is re-scaled -- O&M, battery capex, and linear_constant
# stay national.
#
# IMPORTANT: the PV price that actually drives the cashflow (PV-only payback -> adoption, and
# PV+batt economics) is system_capex_per_kw_combined, which comes from the pv_plus_batt table
# (financial_functions system_costs uses *_combined). So BOTH `pv` and `pv_batt` are made
# state-specific here, with identical per-state PV anchors, so adoption and battery economics
# use the same state price. Consumed by apply_pv_prices / apply_pv_plus_batt_prices, which merge
# on ['state_abbr', ...] when a 'state_abbr' column is present.
# NOTE: baseline only -- policy (*_dollar_per_watt) and the batt-only table stay national.

costs = pd.read_csv('../../input_data/state_upfront_cost_lbnl_2025.csv')
NATIONAL_ANCHOR_PER_W = float(costs.loc[costs['state'] == 'National', 'upfront_cost_per_w'].iloc[0])  # LBNL 2025 national median
costs = costs[costs['state'] != 'National'][['state', 'upfront_cost_per_w']]

DGEN_STATES = ["AL","AR","AZ","CA","CO","CT","DC","DE","FL","GA","IA","ID","IL","IN","KS","KY","LA",
               "MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY",
               "OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"]
vmap = dict(zip(costs['state'], costs['upfront_cost_per_w']))


def make_state_specific(df):
    """Broadcast a national (stacked) res price table to all states, re-anchoring
    system_capex_per_kw to each state's 2026 LBNL upfront cost on the national ATB decline shape."""
    res = df[df['sector_abbr'] == 'res'].copy()
    base_2026 = res.loc[res['year'] == 2026, 'system_capex_per_kw'].values[0]
    res['atb_shape'] = res['system_capex_per_kw'] / base_2026   # scale-invariant decline index
    out = []
    for st in DGEN_STATES:
        anchor_per_kw = vmap.get(st, NATIONAL_ANCHOR_PER_W) * 1000.0   # $/W -> $/kW
        t = res.copy()
        t['state_abbr'] = st
        t['system_capex_per_kw'] = (anchor_per_kw * t['atb_shape']).round(4)
        out.append(t)
    out = pd.concat(out, ignore_index=True).drop(columns=['atb_shape'])
    return out[['state_abbr'] + [c for c in out.columns if c != 'state_abbr']]


pv = make_state_specific(pv)             # -> pv_price_baseline (feeds reporting system_capex_per_kw)
pv_batt = make_state_specific(pv_batt)   # -> pv_plus_batt_baseline (feeds the cashflow *_combined)

n_own = sum(s in vmap for s in DGEN_STATES)
print(f"State-specific baseline: {pv['state_abbr'].nunique()} states x {pv['year'].nunique()} years "
      f"| national fallback = ${NATIONAL_ANCHOR_PER_W:.2f}/W")
print("2026 PV anchors (both tables should match):")
chk = (pv[pv.year == 2026].set_index('state_abbr')['system_capex_per_kw']
       .to_frame('pv_price').join(
       pv_batt[pv_batt.year == 2026].set_index('state_abbr')['system_capex_per_kw'].rename('pv_plus_batt')))
print(chk.loc[['NC','NH','NY','NJ','CA','TX']].to_string())
# Out:
# State-specific baseline: 49 states x 25 years | national fallback = $3.62/W
# 2026 PV anchors (both tables should match):
#             pv_price  pv_plus_batt
# state_abbr
# NC            4096.1        4096.1
# NH            3615.9        3615.9
# NY            3874.6        3874.6
# NJ            3743.5        3743.5
# CA            3339.2        3339.2
# TX            4043.4        4043.4

# %%
# Upload new DFs to Cloud SQL Instance

# Connection config
DB_USER = "postgres"
DB_PASS = "postgres"
DB_NAME = "dgendb"
DB_PORT = 5432
DB_HOST = "127.0.0.1"  # local Cloud SQL Proxy

# Build SQLAlchemy connection string
conn_str = f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

# Create engine
engine = create_engine(conn_str)

# Replace the relevant tables in the database
pv.to_sql("pv_price_baseline", engine, schema="diffusion_shared", if_exists="replace", index=False)
pv_batt.to_sql("pv_plus_batt_baseline", engine, schema="diffusion_shared",  if_exists="replace", index=False)
batt.to_sql("batt_prices_baseline", engine, schema="diffusion_shared", if_exists="replace", index=False)

# Replace the relevant tables in the database
pv_dollar_per_watt.to_sql("pv_price_dollar_per_watt", engine, schema="diffusion_shared", if_exists="replace", index=False)
pv_batt_dollar_per_watt.to_sql("pv_plus_batt_dollar_per_watt", engine, schema="diffusion_shared",  if_exists="replace", index=False)
batt_dollar_per_watt.to_sql("batt_prices_dollar_per_watt", engine, schema="diffusion_shared", if_exists="replace", index=False)

engine.dispose()
